# %%
import pandas as pd

sales = pd.Series([10, 20, 30], index=["영희", "철수", "길동"])
sales
# Out:
# 영희    10
# 철수    20
# 길동    30
# dtype: int64

# %%
sales["철수"]
# Out:
# np.int64(20)

# %%
print(sales["철수"])
# Out:
# 20

# %%
# 평균계산
sales.mean()
# Out:
# np.float64(20.0)

# %%
print(sales.mean())
# Out:
# 20.0

# %%
# 조건 필터링
sales > 15
# Out:
# 영희    False
# 철수     True
# 길동     True
# dtype: bool

# %%
print(sales > 15)
# Out:
# 영희    False
# 철수     True
# 길동     True
# dtype: bool
