# %%
import pandas as pd

# %% [markdown]
# # 🟢 Pandas 파일 불러오기

# %%
# 드라이브 마운트 코드
from google.colab import drive

# Restart the runtime before running this cell.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# csv 파일 불러오기 실습
df = pd.read_csv("/content/drive/MyDrive/코드잇/Pandas/data/body.csv")
df
# Out:
#      height  weight
# 0     188.3    85.8
# 1     176.2    78.0
# 2     175.9    75.6
# 3     181.1    85.1
# 4     182.6    82.3
# ..      ...     ...
# 495   172.0    70.0
# 496   169.6    83.0
# 497   163.3    68.6
# 498   185.7    95.6
# 499   167.7    76.7
#
# [500 rows x 2 columns]

# %% [markdown]
# # 🟢 선 그래프 그리기 - 기본 예시

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [10, 20, 30]) # x값, y값
plt.show()

# %% [markdown]
# ### 그래프 이름 붙이기

# %%
plt.plot([1, 2, 3], [10, 20, 30]) # x값, y값
plt.title("Line graph") # 그래프 타이틀
plt.show()

# %% [markdown]
# ### matplotlib.plot의 다양한 그래프 예시 - 실습 필요 x

# %% [markdown]
# ### 한글이 깨질때
# - !pip install koreanize_matplotlib
# - ! (느낌표)는 코랩을 쓸 경우에 씀
# - 주피터 노트북은 ! 빼도 됨

# %%
# !pip install koreanize_matplotlib

# %% [markdown]
# ### ⚠️ 위 방법으로 안될 경우
# 1. 폰트 설치
# 2. 런타임 -> 세션 다시 시작

# %%
# !apt-get -qq install -y fonts-nanum

# %% [markdown]
# ### ⚠️ 그래도 안될 경우 (1)
# - 캐시삭제 코드

# %%
# matplotlib 캐시 삭제 (중요!)
import shutil
shutil.rmtree('/root/.cache/matplotlib', ignore_errors=True)

# %% [markdown]
# ### ⚠️ 그래도 안될 경우 (2)
# 1. 세션 재시작 후
# 2. 폰트추가

# %%
# 세션 재시작 후 아래코드 실행

import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x) # 사인함수 (삼각함수 - 암기 필요 x)

plt.plot(x, y)
plt.title("사인 그래프") # -> 한글 깨짐 # 한글판을 다운 받아서 설치해야됨
plt.xlabel("X") # X 축의 이름
plt.ylabel("Y") # Y 축의 이름
plt.grid(True) # 그리드(눈금표시)
plt.show()

# %% [markdown]
# ### 구간히 확실히 보이는 라인 그래프

# %%
# 데이터
years = np.array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])
sales = np.array([120, 135, 160, 180, 175, 200, 220, 210, 230, 250])

plt.plot(years, sales, marker='*', linestyle='-', color='teal') # plot -> 라인 그래프 (x: 년도, y: )
plt.title("연도별 판매량")
plt.xlabel("연도")
plt.ylabel("판매량 (천)")
plt.grid(True)
plt.show()

# %%
# 데이터
years = np.array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])
sales = np.array([120, 135, 160, 180, 175, 200, 220, 210, 230, 250])

plt.bar(years, sales, color='orange') # bar -> 막대 그래프
plt.title("연도별 판매량")
plt.xlabel("연도")
plt.ylabel("판매량 (천)")
plt.show()

# %% [markdown]
# # 🟢 산점도 그리기 - 기본 예시

# %%
x = np.random.rand(100)
y = x+np.random.normal(0, 0.1, 100)

plt.scatter(x, y, alpha = 0.5) # scatter -> 산점도 그래프 / alpha -> 투명도
plt.title("산점도 예시")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# # 🟢 히스토그램 그리기 - 기본 예시

# %%
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins = 30, edgecolor='black', color = 'magenta') # bins -> 막대 개수 / edgecolor -> 막대 테두리 색상
plt.title("히스토그램 예시")
plt.xlabel("값")
plt.ylabel("빈도")
plt.show()

# %% [markdown]
# # 🟢 다중 레이아웃 기본
#
# <aside>
#
# - 그래프 사이즈 조절
#   - plt.figure(figsize=(10, 4))
#
# - 그래프 겹침 방지
#   - plt.tight_layout()
# - 그래프 범례 추가
#   - plt.legend()
#
# </aside>

# %%
x = np.linspace(0, 2 * np.pi, 100)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1) # 1행 (한줄) 2열 (2칸)의 첫 번째 그래프를 그리겠다
plt.plot(x, np.sin(x), label="사인 그래프")
plt.title("사인(Sine) 그래프")
plt.legend() # 그래프에 범례 추가

plt.subplot(1, 2, 2) # 1행 (한줄) 2열 (2칸)의 두 번째 그래프를 그리겠다
plt.title("코사인(Cosine) 그래프")
plt.plot(x, np.cos(x), color='red', label="코사인 그래프")
plt.legend() # 그래프에 범례 추가

plt.tight_layout() # 그래프 사이즈 조절 / 눈금끼리 겹치는거 방지
plt.show()

# %% [markdown]
# # 🟢 다중 레이아웃 여러개

# %%
# import random
# import matplotlib.colors as mcolors
#
# def generate_random_color():
#     """Generate a random color hex string."""
#     colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)
#     color_names = list(colors.keys())
#     # Remove white and black colors
#     color_names.remove('w')
#     color_names.remove('k')
#     # Generate a random color name
#     color_name = random.choice(color_names)
#     # Convert the color name to hex
#     color_hex = mcolors.to_hex(colors[color_name])
#     return color_hex

x = np.linspace(0, 2 * np.pi, 100)
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.plot(x, np.sin(x+i), color='red', label = f"사인(x+{i}) 그래프")
    plt.title(f"그래프 {i+1}")
    plt.xticks([]) # x축 눈금 없애기
    plt.yticks([]) # y축 눈금 없애기
    plt.legend() # 그래프에 범례 추가

plt.tight_layout()
plt.show()
