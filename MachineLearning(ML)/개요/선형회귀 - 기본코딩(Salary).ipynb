# %%
import numpy as np
import pandas as pd

# %%
# 파일 마운트
# 드라이브 마운트 코드
from google.colab import drive

# Restart the runtime before running this cell.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/dev/Study_DataSet/training_test_data.csv")
data.head()
# Out:
#    Age  Gender  Experience  Income
# 0   50       1          15     180
# 1   29       1           5     163
# 2   36       1           6     134
# 3   34       2           4     132
# 4   46       1           9     188

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         100 non-null    int64
#  1   Gender      100 non-null    int64
#  2   Experience  100 non-null    int64
#  3   Income      100 non-null    int64
# dtypes: int64(4)
# memory usage: 3.3 KB

# %%
data.describe()
# Out:
#               Age      Gender  Experience      Income
# count  100.000000  100.000000  100.000000  100.000000
# mean    38.880000    1.490000   11.980000  151.890000
# std     12.275688    0.502418   10.458171   28.001405
# min     21.000000    1.000000    0.000000  103.000000
# 25%     28.000000    1.000000    2.000000  127.000000
# 50%     37.000000    1.000000    9.000000  154.000000
# 75%     50.000000    2.000000   21.000000  174.000000
# max     60.000000    2.000000   33.000000  200.000000

# %%
# df -> numpy 배열로 변환
data_np = data.values

# %%
data_np
# Out:
# array([[ 50,   1,  15, 180],
#        [ 29,   1,   5, 163],
#        [ 36,   1,   6, 134],
#        [ 34,   2,   4, 132],
#        [ 46,   1,   9, 188],
#        [ 33,   1,   3, 127],
#        [ 26,   2,   8, 141],
#        [ 23,   1,   5, 122],
#        [ 48,   1,   7, 169],
#        [ 24,   1,   5, 114],
#        [ 44,   1,  10, 174],
#        [ 60,   1,  25, 190],
#        [ 51,   2,  17, 190],
#        [ 24,   2,   1, 110],
#        [ 28,   1,   2, 120],
#        [ 32,   1,   3, 130],
#        [ 46,   1,  12, 165],
#        [ 39,   1,  10, 170],
#        [ 23,   2,   3, 120],
#        [ 28,   1,   1, 130],
#        [ 33,   1,   3, 133],
#        [ 48,   2,  15, 167],
#        [ 39,   1,   6, 155],
#        [ 40,   1,   9, 159],
#        [ 46,   1,  13, 179],
#        [ 49,   2,  22, 200],
#        [ 28,   1,   3, 120],
#        [ 30,   2,   1, 145],
#        [ 52,   2,  27, 181],
#        [ 51,   2,  21, 198],
#        [ 22,   2,   1, 112],
#        [ 31,   2,   4, 143],
# ...

# %% [markdown]
# # 종속 vs 독립변수 구분

# %%
y = data_np[:,-1]
X = data_np[:, :-1]

# %% [markdown]
# # 선형 회귀 계산식 방정식
# ![스크린샷 2025-05-22 오전 11.01.04.png](data:image/png;base64,...)

# %%
b = np.dot(
        np.linalg.inv(np.dot(X.T, X)),   # (XᵀX)^(-1)
        np.dot(X.T, y)                   # Xᵀy
    )

# %%
b
# Out:
# array([ 4.41868053,  8.71283132, -2.83170131])

# %% [markdown]
# # 소득 = 4.42xAge + 8.71xGender - 2.83xExperience

# %% [markdown]
# 두 번째 모델

# %%
# np.c_(): 열방향으로 붙임

X2 = np.c_[np.ones(100), X]

# %%
X2
# Out:
# array([[ 1., 50.,  1., 15.],
#        [ 1., 29.,  1.,  5.],
#        [ 1., 36.,  1.,  6.],
#        [ 1., 34.,  2.,  4.],
#        [ 1., 46.,  1.,  9.],
#        [ 1., 33.,  1.,  3.],
#        [ 1., 26.,  2.,  8.],
#        [ 1., 23.,  1.,  5.],
#        [ 1., 48.,  1.,  7.],
#        [ 1., 24.,  1.,  5.],
#        [ 1., 44.,  1., 10.],
#        [ 1., 60.,  1., 25.],
#        [ 1., 51.,  2., 17.],
#        [ 1., 24.,  2.,  1.],
#        [ 1., 28.,  1.,  2.],
#        [ 1., 32.,  1.,  3.],
#        [ 1., 46.,  1., 12.],
#        [ 1., 39.,  1., 10.],
#        [ 1., 23.,  2.,  3.],
#        [ 1., 28.,  1.,  1.],
#        [ 1., 33.,  1.,  3.],
#        [ 1., 48.,  2., 15.],
#        [ 1., 39.,  1.,  6.],
#        [ 1., 40.,  1.,  9.],
#        [ 1., 46.,  1., 13.],
#        [ 1., 49.,  2., 22.],
#        [ 1., 28.,  1.,  3.],
#        [ 1., 30.,  2.,  1.],
#        [ 1., 52.,  2., 27.],
#        [ 1., 51.,  2., 21.],
#        [ 1., 22.,  2.,  1.],
#        [ 1., 31.,  2.,  4.],
# ...

# %%
b2 = np.dot(
        np.linalg.inv(np.dot(X.T, X)),   # (XᵀX)^(-1)
        np.dot(X.T, y)                   # Xᵀy
    )

# %% [markdown]
# # 소득 = 68.88 + 2.36xAge - 0.9xGender - 0.63xExperience

# %% [markdown]
# # sklearn 으로 실습
# 1. 데이터 불러오기
# 2. 데이터 프레임 -> 넘파이 변환
# 3. 독립, 종속변수 변환
# 똑같음

# %%
from sklearn.model_selection import train_test_split # 테스트 데이터와 트레인 데이터 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape
# Out:
# (70, 3)

# %%
X_test.shape
# Out:
# (30, 3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.6550869047658956

# %%
model.score(X_test, y_test)
# Out:
# 0.6940920052930267

# %% [markdown]
# # 모델 평가하기
# R 스퀘어

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train, model.predict(X_train))
